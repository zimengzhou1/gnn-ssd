# %%
path = '/mnt/raid0nvme1/zz/cache_data/'

# %%
import json
import os
import os.path as osp
import numpy as np
import matplotlib.pyplot as plt

datasets = ['overflow']
master_dict = {}

for i in datasets:
  __file__ = os.path.abspath('')
  path = '/mnt/raid0nvme1/zz/cache_data/' + i
  path = './results/' + i
  print(path)

  startName = path + "/meta_" + i + "_subset_50.0Cache_"
  if (i == 'taobao'):
     startName = path + "/meta_" + i + "_subset_1.0Cache_"
  if (i == 'overflow'):
     startName = path + "/out_deg_use_all/meta_" + i + "_subset_2.0Cache_"
  endName = "Size_10_5.json"

  fileNames = [startName + str(i) + endName for i in [2,5,10,20,40,60,80]]
  res = []
  for j in fileNames:
      with open(j) as json_file:
        data = json.load(json_file)
      #   res.append((data['LRUAccuracy'], data['StaticAccuracy'], data['LFUAccuracy'], data['ARCAccuracy'], data['LFUImpAccuracy']))
      res.append((data['LRUAccuracy'], data['StaticAccuracy'], data['LFUAccuracy'], data['ARCAccuracy']))
  master_dict[i] = res
# Out:
# ./results/overflow

# %%
#overflow = master_dict['overflow']
#taobao = master_dict['taobao']
#reddit = master_dict['reddit']
wiki = master_dict['wiki']
wiki
# Out:
# [(1383557,
#   0.17997451496396608,
#   249005,
#   0.20300283978180877,
#   280866,
#   0.15469908359395385,
#   214035,
#   0.24921705430278623,
#   344806),
#  (1383350,
#   0.37572487078468936,
#   519759,
#   0.35949831929735787,
#   497312,
#   0.3037430874326815,
#   420183,
#   0.4295471138901941,
#   594214),
#  (1383997,
#   0.5582071348420553,
#   772557,
#   0.4947814193238858,
#   684776,
#   0.47621924035962504,
#   659086,
#   0.5943293229681856,
#   822550),
#  (1383326,
#   0.7406504323637378,
#   1024561,
#   0.6220052250879402,
#   860436,
#   0.6449145031612216,
#   892127,
#   0.7548249653371656,
#   1044169),
#  (1383151,
#   0.8795879842475622,
#   1216603,
#   0.717633143452884,
#   992595,
#   0.8091647260494335,
#   1119197,
#   0.8818841905186057,
#   1219779),
#  (1382729,
#   0.9389258488105767,
#   1298280,
#   0.7929529213605847,
#   1096439,
#   0.9032760577090666,
#   1248986,
#   0.939263586718728,
#   1298747),
#  (1383094,
#   0.9733141782120377,
#   1346185,
#   0.926224103350893,
#   1281055,
#   0.962039456464998,
#   1330591,
#   0.97342407674388,
#   1346337)]

# %%
import numpy as np
import matplotlib.pyplot as plt

xs = [2, 5, 10, 20, 40, 60, 80]

# # Reddit
# reddit_LRUAccuracy = [i[0] for i in master_dict['reddit']]
# reddit_LFUAccuracy = [i[2] for i in master_dict['reddit']]
# reddit_ARCAccuracy = [i[3] for i in master_dict['reddit']]
# reddit_StaticAccuracy = [i[1] for i in master_dict['reddit']]
# reddit_LFUImpAccuracy = [i[4] for i in master_dict['reddit']]

# # Wiki
# wiki_LRUAccuracy = [i[0] for i in master_dict['wiki']]
# wiki_LFUAccuracy = [i[2] for i in master_dict['wiki']]
# wiki_ARCAccuracy = [i[3] for i in master_dict['wiki']]
# wiki_StaticAccuracy = [i[1] for i in master_dict['wiki']]
# wiki_LFUImpAccuracy = [i[4] for i in master_dict['wiki']]

# # Taobao
# taobao_LRUAccuracy = [i[0] for i in master_dict['taobao']]
# taobao_LFUAccuracy = [i[2] for i in master_dict['taobao']]
# taobao_ARCAccuracy = [i[3] for i in master_dict['taobao']]
# taobao_StaticAccuracy = [i[1] for i in master_dict['taobao']]
# taobao_LFUImpAccuracy = [i[4] for i in master_dict['taobao']]

# Overflow
LRUAccuracy = [i[0] for i in master_dict['overflow']]
LFUAccuracy = [i[2] for i in master_dict['overflow']]
ARCAccuracy = [i[3] for i in master_dict['overflow']]
StaticAccuracy = [i[1] for i in master_dict['overflow']]
#LFUImpAccuracy = [i[4] for i in master_dict['overflow']]


# plt.plot(xs, LRUAccuracy, 'o-', color='red', label="Overflow")
# plt.plot(xs, reddit_LRUAccuracy, 'o-', color='blue', label="Reddit")
# plt.plot(xs, wiki_LRUAccuracy, 'o-', color='orange', label="Wiki")
# plt.plot(xs, taobao_LRUAccuracy, 'o-', color='green', label="Taobao")
# plt.legend()
# plt.title("LRU")
# plt.xlabel('Cache size %')
# plt.ylabel('Cache hit ratio %')

# %%
plt.plot(xs, LFUAccuracy, 'o-', color='red', label="Overflow")
plt.plot(xs, reddit_LFUAccuracy, 'o-', color='blue', label="Reddit")
plt.plot(xs, wiki_LFUAccuracy, 'o-', color='orange', label="Wiki")
plt.plot(xs, taobao_LFUAccuracy, 'o-', color='green', label="Taobao")
plt.plot(xs, StaticAccuracy, 'x-', color='red', label="OverflowS")
plt.plot(xs, reddit_StaticAccuracy, 'x-', color='blue', label="RedditS")
plt.plot(xs, wiki_StaticAccuracy, 'x-', color='orange', label="WikiS")
plt.plot(xs, taobao_StaticAccuracy, 'x-', color='green', label="TaobaoS")
plt.legend()
plt.title("LFU")
plt.xlabel('Cache size %')
plt.ylabel('Cache hit ratio %')
# Out:
# Text(0, 0.5, 'Cache hit ratio %')

# %%
plt.plot(xs, LRUAccuracy, 'o-', color='red', label="LRU")
plt.plot(xs, LFUAccuracy, 'o-', color='blue', label="LFU")
plt.plot(xs, ARCAccuracy, 'o-', color='orange', label="ARC")
plt.plot(xs, StaticAccuracy, 'o-', color='green', label="Static")
#plt.plot(xs, LFUImpAccuracy, 'o-', color='purple', label="LFU Improved")
plt.legend()
plt.title("Overflow")
plt.xlabel('Cache size %')
plt.ylabel('Cache hit ratio %')
# Out:
# Text(0, 0.5, 'Cache hit ratio %')

# %%
plt.plot(xs, LRUAccuracy, 'o-', color='red', label="LRU")
plt.plot(xs, LFUAccuracy, 'o-', color='blue', label="LFU")
plt.plot(xs, ARCAccuracy, 'o-', color='orange', label="ARC")
plt.plot(xs, StaticAccuracy, 'o-', color='green', label="Static")
#plt.plot(xs, LFUImpAccuracy, 'o-', color='purple', label="LFU Improved")
plt.legend()
plt.title("Overflow")
plt.xlabel('Cache size %')
plt.ylabel('Cache hit ratio %')
# Out:
# Text(0, 0.5, 'Cache hit ratio %')

# %%
plt.plot(xs, LRUAccuracy, 'o-', color='red', label="LRU")
plt.plot(xs, LFUAccuracy, 'o-', color='blue', label="LFU")
plt.plot(xs, ARCAccuracy, 'o-', color='orange', label="ARC")
plt.plot(xs, StaticAccuracy, 'o-', color='green', label="Static")
plt.plot(xs, LFUImpAccuracy, 'o-', color='purple', label="LFU Improved")
plt.legend()
plt.title("Overflow")
plt.xlabel('Cache size %')
plt.ylabel('Cache hit ratio %')
# Out:
# Text(0, 0.5, 'Cache hit ratio %')

# %%
plt.plot(xs, LRUAccuracy, 'o-', color='red', label="LRU")
plt.plot(xs, LFUAccuracy, 'o-', color='blue', label="LFU")
plt.plot(xs, ARCAccuracy, 'o-', color='orange', label="ARC")
plt.plot(xs, StaticAccuracy, 'o-', color='green', label="Static")
plt.legend()
plt.title("Overflow")
plt.xlabel('Cache size %')
plt.ylabel('Cache hit ratio %')
# Out:
# Text(0, 0.5, 'Cache hit ratio %')

# %%
plt.plot(xs, reddit_LRUAccuracy, 'o-', color='red', label="LRU")
plt.plot(xs, reddit_LFUAccuracy, 'o-', color='blue', label="LFU")
plt.plot(xs, reddit_ARCAccuracy, 'o-', color='orange', label="ARC")
plt.plot(xs, reddit_StaticAccuracy, 'o-', color='green', label="Static")
plt.plot(xs, reddit_LFUImpAccuracy, 'o-', color='purple', label="LFU Improved")
plt.legend()
plt.title("Reddit")
plt.xlabel('Cache size %')
plt.ylabel('Cache hit ratio %')
# Out:
# Text(0, 0.5, 'Cache hit ratio %')

# %%
plt.plot(xs, reddit_LRUAccuracy, 'o-', color='red', label="LRU")
plt.plot(xs, reddit_LFUAccuracy, 'o-', color='blue', label="LFU")
plt.plot(xs, reddit_ARCAccuracy, 'o-', color='orange', label="ARC")
plt.plot(xs, reddit_StaticAccuracy, 'o-', color='green', label="Static")
plt.plot(xs, reddit_LFUImpAccuracy, 'o-', color='purple', label="LFU Improved")
plt.legend()
plt.title("Reddit")
plt.xlabel('Cache size %')
plt.ylabel('Cache hit ratio %')
# Out:
# Text(0, 0.5, 'Cache hit ratio %')

# %%
plt.plot(xs, wiki_LRUAccuracy, 'o-', color='red', label="LRU")
plt.plot(xs, wiki_LFUAccuracy, 'o-', color='blue', label="LFU")
plt.plot(xs, wiki_ARCAccuracy, 'o-', color='orange', label="ARC")
plt.plot(xs, wiki_StaticAccuracy, 'o-', color='green', label="Static")
plt.plot(xs, wiki_LFUImpAccuracy, 'o-', color='purple', label="LFU Improved")
plt.legend()
plt.title("Wikipedia")
plt.xlabel('Cache size %')
plt.ylabel('Cache hit ratio %')
# Out:
# Text(0, 0.5, 'Cache hit ratio %')

# %%
plt.plot(xs, taobao_LRUAccuracy, 'o-', color='red', label="LRU")
plt.plot(xs, taobao_LFUAccuracy, 'o-', color='blue', label="LFU")
plt.plot(xs, taobao_ARCAccuracy, 'o-', color='orange', label="ARC")
plt.plot(xs, taobao_StaticAccuracy, 'o-', color='green', label="Static")
plt.plot(xs, taobao_LFUImpAccuracy, 'o-', color='purple', label="LFU Improved")
plt.legend()
plt.title("Taobao")
plt.xlabel('Cache size %')
plt.ylabel('Cache hit ratio %')
# Out:
# Text(0, 0.5, 'Cache hit ratio %')

# %%
# Find number of cache hits instead of ratio

import json
import os
import os.path as osp
import numpy as np
import matplotlib.pyplot as plt

datasets = ['wiki', 'reddit']
master_dict = {}

for i in datasets:
  __file__ = os.path.abspath('')
  path = '/mnt/raid0nvme1/zz/cache_data/' + i
  path = './results/' + i
  print(path)

  startName = path + "/compare_tgl/meta_" + i + "_subset_20.0Cache_"
  if (i == 'taobao'):
     startName = path + "/meta_" + i + "_subset_1.0Cache_"
  if (i == 'overflow'):
     startName = path + "/out_deg_use_all/meta_" + i + "_subset_2.0Cache_"
  endName = "Size_10_5.json"

  fileNames = [startName + str(i) + endName for i in [2,5,10,20,40,60,80]]
  res = []
  for j in fileNames:
      with open(j) as json_file:
        data = json.load(json_file)
      #   res.append((data['LRUAccuracy'], data['StaticAccuracy'], data['LFUAccuracy'], data['ARCAccuracy'], data['LFUImpAccuracy']))
      res.append((data['total'], data['LRUAccuracy'], data['LRU_hits'], data['StaticAccuracy'], data['Static_hits'], data['LFUAccuracy'], data['LFU_hits'], data['ARCAccuracy'], data['ARC_hits']))
  master_dict[i] = res
# Out:
# ./results/wiki
# ./results/reddit

# %%
#overflow = master_dict['overflow']
#taobao = master_dict['taobao']
reddit = master_dict['reddit']
wiki = master_dict['wiki']

# %%
import numpy as np
import matplotlib.pyplot as plt

xs = [2, 5, 10, 20, 40, 60, 80]

# # Reddit
total = master_dict['wiki'][0][0]
reddit_LRUAccuracy = [i[1] for i in master_dict['reddit']]
reddit_LRUMisses = [total - i[2] for i in master_dict['reddit']]

reddit_LFUAccuracy = [i[5] for i in master_dict['reddit']]
reddit_LFUMisses = [total - i[6] for i in master_dict['reddit']]

reddit_ARCAccuracy = [i[7] for i in master_dict['reddit']]
reddit_ARCMisses = [total - i[8] for i in master_dict['reddit']]

reddit_StaticAccuracy = [i[3] for i in master_dict['reddit']]
reddit_StaticMisses = [total - i[4] for i in master_dict['reddit']]

# # Wiki
total = master_dict['wiki'][0][0]
wiki_LRUAccuracy = [i[1] for i in master_dict['wiki']]
wiki_LRUMisses = [total - i[2] for i in master_dict['wiki']]

wiki_LFUAccuracy = [i[5] for i in master_dict['wiki']]
wiki_LFUMisses = [total - i[6] for i in master_dict['wiki']]

wiki_ARCAccuracy = [i[7] for i in master_dict['wiki']]
wiki_ARCMisses = [total - i[8] for i in master_dict['wiki']]

wiki_StaticAccuracy = [i[3] for i in master_dict['wiki']]
wiki_StaticMisses = [total - i[4] for i in master_dict['wiki']]

# # Taobao
# taobao_LRUAccuracy = [i[0] for i in master_dict['taobao']]
# taobao_LFUAccuracy = [i[2] for i in master_dict['taobao']]
# taobao_ARCAccuracy = [i[3] for i in master_dict['taobao']]
# taobao_StaticAccuracy = [i[1] for i in master_dict['taobao']]
# taobao_LFUImpAccuracy = [i[4] for i in master_dict['taobao']]

# Overflow
# LRUAccuracy = [i[0] for i in master_dict['overflow']]
# LFUAccuracy = [i[2] for i in master_dict['overflow']]
# ARCAccuracy = [i[3] for i in master_dict['overflow']]
# StaticAccuracy = [i[1] for i in master_dict['overflow']]
#LFUImpAccuracy = [i[4] for i in master_dict['overflow']]


# plt.plot(xs, LRUAccuracy, 'o-', color='red', label="Overflow")
# plt.plot(xs, reddit_LRUAccuracy, 'o-', color='blue', label="Reddit")
# plt.plot(xs, wiki_LRUAccuracy, 'o-', color='orange', label="Wiki")
# plt.plot(xs, taobao_LRUAccuracy, 'o-', color='green', label="Taobao")
# plt.legend()
# plt.title("LRU")
# plt.xlabel('Cache size %')
# plt.ylabel('Cache hit ratio %')

# %%
plt.plot(xs, wiki_LRUAccuracy, 'o-', color='red', label="LRU")
plt.plot(xs, wiki_LFUAccuracy, 'o-', color='blue', label="LFU")
plt.plot(xs, wiki_ARCAccuracy, 'o-', color='orange', label="ARC")
plt.plot(xs, wiki_StaticAccuracy, 'o-', color='green', label="Static")
plt.legend()
plt.title("Wikipedia")
plt.xlabel('Cache size %')
plt.ylabel('Cache hit ratio %')
# Out:
# Text(0, 0.5, 'Cache hit ratio %')

# %%
plt.plot(xs, reddit_LRUAccuracy, 'o-', color='red', label="LRU")
plt.plot(xs, reddit_LFUAccuracy, 'o-', color='blue', label="LFU")
plt.plot(xs, reddit_ARCAccuracy, 'o-', color='orange', label="ARC")
plt.plot(xs, reddit_StaticAccuracy, 'o-', color='green', label="Static")
plt.legend()
plt.title("Reddit")
plt.xlabel('Cache size %')
plt.ylabel('Cache hit ratio %')
# Out:
# Text(0, 0.5, 'Cache hit ratio %')

# %%
LRU_temporal = [454884, 330685, 232001, 137158, 60140, 28073, 12091]
LFU_temporal = [541231, 456651, 362859, 231956, 101910, 41196, 13966]
ARC_temporal = [428631, 315465, 222450, 132444, 58543, 27371, 11829]
Static_temporal = [578223, 511565, 434647, 320233, 190300, 101562, 45431]

# %%
plt.plot(xs, wiki_LRUMisses, 'o-', color='red', label="LRU")
plt.plot(xs, LRU_temporal, 'x--', color='red', label="LRU temporal")
plt.plot(xs, wiki_LFUMisses, 'o-', color='blue', label="LFU")
plt.plot(xs, LFU_temporal, 'x--', color='blue', label="LFU temporal")
plt.plot(xs, wiki_ARCMisses, 'o-', color='orange', label="ARC")
plt.plot(xs, ARC_temporal, 'x--', color='orange', label="ARC temporal")
plt.plot(xs, wiki_StaticMisses, 'o-', color='green', label="Static")
plt.plot(xs, Static_temporal, 'x--', color='green', label="Static temporal")
plt.legend()
plt.title("Wikipedia")
plt.xlabel('Cache size %')
plt.ylabel('Cache misses count')
# Out:
# Text(0, 0.5, 'Cache misses count')
